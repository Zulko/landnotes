# %%
# Submit selected pages to Gemini

This file submits the sets of pages selected by the `select_pages_for_gemini.ipynb` notebook to Gemini.

Instead of submitting all pages (there are ~4 million pages with dates which might cost $3000 total), we submit only pages selected to fit a $300 budget.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from wiki_dump_extractor import WikiAvroDumpExtractor, llm_utils
import json
import db_utils
import tempfile
from tqdm.auto import tqdm

model_name = "gemini-2.0-flash"
wiki_dump = WikiAvroDumpExtractor("wiki_dump.avro", index_dir="wiki_dump_idx")

# %%
def process_batch(pages_batch_and_index):
    pages_batch, index = pages_batch_and_index
    batch_name = f"batch_{index}"
    requests = [
        llm_utils.PageEventExtractionRequest.from_page(
            page=page,
            model_settings={"temperature": 0, "top_p": 0.95},
        )
        for page in pages_batch
    ]
    with tempfile.NamedTemporaryFile(delete=False, suffix=".jsonl") as f:
        llm_utils.PageEventExtractionRequest.list_to_batch_jsonl(
            requests=requests, path=f.name
        )
        return llm_utils.process_batch_request(
            jsonl_path=f.name,
            batch_name=batch_name,
            bucket_name="wikipage-extraction",
            model=model_name,
        )


all_events = 0
all_usage = {"promptTokenCount": 0, "candidatesTokenCount": 0}
all_failed = {}
all_errored = {}


def process_dump(dump, db_path):
    all_events = 0
    all_usage = {"promptTokenCount": 0, "candidatesTokenCount": 0}
    all_failed = {}
    all_errored = {}
    with db_utils.open_plyvel_db(db_path, replace=False) as events_by_page_db:
        batches_being_processed = dump.process_page_batches_in_parallel(
            process_fn=process_batch,
            batch_size=1_000,
            page_filter=lambda p: not events_by_page_db.get(p.title.encode("utf-8")),
            num_workers=2,
        )

        for batch_result in tqdm(batches_being_processed):
            events_by_page, failed, errored, usage = batch_result
            all_events += sum(len(events) for events in events_by_page.values())
            all_failed.update(failed)
            all_errored.update(errored)
            all_usage["promptTokenCount"] += usage["promptTokenCount"]
            all_usage["candidatesTokenCount"] += usage["candidatesTokenCount"]
            for page_title, data in failed.items():
                data = json.dumps(data).encode("utf-8")
                events_by_page_db.put(page_title.encode("utf-8"), data)

            for page_title, error in errored.items():
                events_by_page_db.put(page_title.encode("utf-8"), error.encode("utf-8"))

            for page_title, events in events_by_page.items():
                events_json = json.dumps(events).encode("utf-8")
                events_by_page_db.put(page_title.encode("utf-8"), events_json)

    return all_events, all_usage, all_failed, all_errored

# %% [markdown]
# ## Top historical pages

# %%
historical_dump = WikiAvroDumpExtractor("historical_pages.avro")
historical_pages = set([p.title for p in historical_dump.iter_pages()])
len(historical_pages)
if False:
    all_events, all_usage, all_failed, all_errored = process_dump(
        historical_dump, db_path=f"events_extracted_by_page_{model_name}_db"
    )
    print("Failed", len(all_failed))
    print("Errored", len(all_errored))
    print("Events", all_events)
    print("Usage", all_usage)
# Out:
# ---------------------------------------------------------------------------
# EOFError                                  Traceback (most recent call last)
# File fastavro/_read.pyx:1046, in fastavro._read.file_reader.__init__()
#
# File fastavro/_read.pyx:765, in fastavro._read._read_data()
#
# File fastavro/_read.pyx:638, in fastavro._read.read_record()
#
# File fastavro/_read.pyx:737, in fastavro._read._read_data()
#
# File fastavro/_read.pyx:316, in fastavro._read.read_fixed()
#
# EOFError: Expected 4 bytes, read 0
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 2
#       1 historical_dump = WikiAvroDumpExtractor("historical_pages.avro")
# ----> 2 historical_pages = set([p.title for p in historical_dump.iter_pages()])
#       3 len(historical_pages)
#       4 if False:
#
# Cell In[4], line 2, in <listcomp>(.0)
#       1 historical_dump = WikiAvroDumpExtractor("historical_pages.avro")
# ----> 2 historical_pages = set([p.title for p in historical_dump.iter_pages()])
#       3 len(historical_pages)
#       4 if False:
#
# File ~/Documents/programming/python/wikidump_extractor/src/wiki_dump_extractor/wiki_dump_extractor.py:134, in ExtractorBase.iter_pages(self, page_limit, page_filter)
#     128 """Iterate over all pages in the dump file.
#     129
#     130 The returned elements are Page objects with fields title, page_id,
#     131 timestamp, redirect_title, revision_id, and text.
#     132 """
#     133 page_count = 0
# --> 134 for page in self._iter_pages():
#     135     if page_filter is None or page_filter(page):
#     136         yield page
#
# File ~/Documents/programming/python/wikidump_extractor/src/wiki_dump_extractor/wiki_dump_extractor.py:456, in WikiAvroDumpExtractor._iter_pages(self)
#     449 """Iterate over all pages in the Avro file.
#     450
#     451 The returned elements are Page objects with fields title, page_id,
#     452 timestamp, redirect_title, revision_id, and text, depending on what
#     453 was saved in the Avro file.
#     454 """
#     455 with open(self.file_path, "rb") as f:
# --> 456     reader = fastavro.reader(f)
#     457     for record in reader:
#     458         yield Page(**record)
#
# File fastavro/_read.pyx:1119, in fastavro._read.reader.__init__()
#
# File fastavro/_read.pyx:1048, in fastavro._read.file_reader.__init__()
#
# ValueError: cannot read header - is it an avro file?

# %% [markdown]
# ## Top places

# %%
places_dump = WikiAvroDumpExtractor("geospatial/places_with_over_20_dates.avro")
places_pages = set([p.title for p in places_dump.iter_pages()])
len(places_pages)
# Out:
# 117871

# %%
if False:
    all_events, all_usage, all_failed, all_errored = process_dump(
        places_dump, db_path=f"events_extracted_by_page_{model_name}_db"
    )
    print("Failed", len(all_failed))
    print("Errored", len(all_errored))
    print("Events", all_events)
    print("Usage", all_usage)

# %% [markdown]
# ## BC pages

# %%
import glob
from pathlib import Path

target = Path("negative_dates_dump.avro")
if not target.exists():
    pages_with_negative_dates = set()
    for file_path in glob.glob("dates_by_year/-*.avro"):
        df = db_utils.avro_to_pandas(file_path)
        pages_with_negative_dates.update(set(df.page))

    pages_with_negative_dates = sorted(pages_with_negative_dates)
    print(f"Total pages in negative year files: {len(pages_with_negative_dates)}")
    wiki_dump.extract_pages_titles_to_new_dump(pages_with_negative_dates, target)

# %%
negative_dates_dump = WikiAvroDumpExtractor(target)
if False:
    all_events, all_usage, all_failed, all_errored = process_dump(
        negative_dates_dump, db_path=f"events_extracted_by_page_{model_name}_db"
    )
    print("Failed", len(all_failed))
    print("Errored", len(all_errored))
    print("Events", all_events)
    print("Usage", all_usage)

# %% [markdown]
# ## 1949 pages

# %%
dates_1949_df = db_utils.avro_to_pandas("dates_by_year/1949.avro")
pages_1949 = list(set(dates_1949_df.page))
len(pages_1949)
# Out:
# 116731

# %%
target = Path("y1949_dump.avro")
if not target.exists():
    wiki_dump.extract_pages_titles_to_new_dump(pages_1949, target)
y1949_dump = WikiAvroDumpExtractor(target)
if False:
    all_events, all_usage, all_failed, all_errored = process_dump(
        y1949_dump, db_path=f"events_extracted_by_page_{model_name}_db"
    )
    print("Failed", len(all_failed))
    print("Errored", len(all_errored))
    print("Events", all_events)
    print("Usage", all_usage)
# Out:
# 0it [00:00, ?it/s]

# %% [markdown]
# ## Pages 400-1949 with over 10 events

# %%
with open("pages_250_1920_with_over_10_dates.json", "r") as f:
    y250_1920_10plus_event_pages = json.load(f)

# %%
target = Path("y250_1920_10plus_events_dump.avro")
if not target.exists():
    wiki_dump.extract_pages_titles_to_new_dump(y250_1920_10plus_event_pages, target)
# Out:
# 0it [00:00, ?it/s]

# %%
y250_1920_10plus_events_dump = WikiAvroDumpExtractor(target)
if False:
    all_events, all_usage, all_failed, all_errored = process_dump(
        y250_1920_10plus_events_dump,
        db_path=f"events_extracted_by_page_{model_name}_db",
    )
    print("Failed", len(all_failed))
    print("Errored", len(all_errored))
    print("Events", all_events)
    print("Usage", all_usage)
# Out:
# 0it [00:00, ?it/s]
# gs://wikipage-extraction/batch_1/batch_1.jsonl
# Launching batch_1...
# Creating BatchPredictionJob
# BatchPredictionJob created. Resource name: projects/39028607318/locations/us-central1/batchPredictionJobs/6875829654020685824
# To use this BatchPredictionJob in another session:
# bpj = aiplatform.BatchPredictionJob('projects/39028607318/locations/us-central1/batchPredictionJobs/6875829654020685824')
# View Batch Prediction Job:
# https://console.cloud.google.com/ai/platform/locations/us-central1/batch-predictions/6875829654020685824?project=39028607318
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/6875829654020685824 current state:
# 3
# gs://wikipage-extraction/batch_0/batch_0.jsonl
# Launching batch_0...
# Creating BatchPredictionJob
# BatchPredictionJob created. Resource name: projects/39028607318/locations/us-central1/batchPredictionJobs/66387017436495872
# To use this BatchPredictionJob in another session:
# bpj = aiplatform.BatchPredictionJob('projects/39028607318/locations/us-central1/batchPredictionJobs/66387017436495872')
# View Batch Prediction Job:
# https://console.cloud.google.com/ai/platform/locations/us-central1/batch-predictions/66387017436495872?project=39028607318
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/66387017436495872 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/6875829654020685824 current state:
# 3
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/66387017436495872 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/6875829654020685824 current state:
# 3
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/66387017436495872 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/6875829654020685824 current state:
# 3
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/66387017436495872 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/6875829654020685824 current state:
# 3
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/66387017436495872 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/6875829654020685824 current state:
# 3
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/66387017436495872 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/6875829654020685824 current state:
# 4
# BatchPredictionJob run completed. Resource name: projects/39028607318/locations/us-central1/batchPredictionJobs/6875829654020685824
# Batch job projects/39028607318/locations/us-central1/batchPredictionJobs/6875829654020685824 started. Waiting for completion...
# Downloading and parsing results for batch_1...
# gs://wikipage-extraction/batch_2/batch_2.jsonl
# Launching batch_2...
# Creating BatchPredictionJob
# BatchPredictionJob created. Resource name: projects/39028607318/locations/us-central1/batchPredictionJobs/2774281846509273088
# To use this BatchPredictionJob in another session:
# bpj = aiplatform.BatchPredictionJob('projects/39028607318/locations/us-central1/batchPredictionJobs/2774281846509273088')
# View Batch Prediction Job:
# https://console.cloud.google.com/ai/platform/locations/us-central1/batch-predictions/2774281846509273088?project=39028607318
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/2774281846509273088 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/2774281846509273088 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/2774281846509273088 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/2774281846509273088 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/2774281846509273088 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/66387017436495872 current state:
# 3
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/2774281846509273088 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/66387017436495872 current state:
# 4
# BatchPredictionJob run completed. Resource name: projects/39028607318/locations/us-central1/batchPredictionJobs/66387017436495872
# Batch job projects/39028607318/locations/us-central1/batchPredictionJobs/66387017436495872 started. Waiting for completion...
# Downloading and parsing results for batch_0...
# gs://wikipage-extraction/batch_3/batch_3.jsonl
# Launching batch_3...
# Creating BatchPredictionJob
# BatchPredictionJob created. Resource name: projects/39028607318/locations/us-central1/batchPredictionJobs/8275323238226067456
# To use this BatchPredictionJob in another session:
# bpj = aiplatform.BatchPredictionJob('projects/39028607318/locations/us-central1/batchPredictionJobs/8275323238226067456')
# View Batch Prediction Job:
# https://console.cloud.google.com/ai/platform/locations/us-central1/batch-predictions/8275323238226067456?project=39028607318
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/8275323238226067456 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/8275323238226067456 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/8275323238226067456 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/8275323238226067456 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/8275323238226067456 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/2774281846509273088 current state:
# 3
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/8275323238226067456 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/2774281846509273088 current state:
# 4
# BatchPredictionJob run completed. Resource name: projects/39028607318/locations/us-central1/batchPredictionJobs/2774281846509273088
# Batch job projects/39028607318/locations/us-central1/batchPredictionJobs/2774281846509273088 started. Waiting for completion...
# Downloading and parsing results for batch_2...
# gs://wikipage-extraction/batch_4/batch_4.jsonl
# Launching batch_4...
# Creating BatchPredictionJob
# BatchPredictionJob created. Resource name: projects/39028607318/locations/us-central1/batchPredictionJobs/1180007578420117504
# To use this BatchPredictionJob in another session:
# bpj = aiplatform.BatchPredictionJob('projects/39028607318/locations/us-central1/batchPredictionJobs/1180007578420117504')
# View Batch Prediction Job:
# https://console.cloud.google.com/ai/platform/locations/us-central1/batch-predictions/1180007578420117504?project=39028607318
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/1180007578420117504 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/1180007578420117504 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/1180007578420117504 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/1180007578420117504 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/1180007578420117504 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/8275323238226067456 current state:
# 3
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/1180007578420117504 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/8275323238226067456 current state:
# 4
# BatchPredictionJob run completed. Resource name: projects/39028607318/locations/us-central1/batchPredictionJobs/8275323238226067456
# Batch job projects/39028607318/locations/us-central1/batchPredictionJobs/8275323238226067456 started. Waiting for completion...
# Downloading and parsing results for batch_3...
# gs://wikipage-extraction/batch_5/batch_5.jsonl
# Launching batch_5...
# Creating BatchPredictionJob
# BatchPredictionJob created. Resource name: projects/39028607318/locations/us-central1/batchPredictionJobs/7301525371923464192
# To use this BatchPredictionJob in another session:
# bpj = aiplatform.BatchPredictionJob('projects/39028607318/locations/us-central1/batchPredictionJobs/7301525371923464192')
# View Batch Prediction Job:
# https://console.cloud.google.com/ai/platform/locations/us-central1/batch-predictions/7301525371923464192?project=39028607318
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/7301525371923464192 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/7301525371923464192 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/7301525371923464192 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/7301525371923464192 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/7301525371923464192 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/1180007578420117504 current state:
# 3
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/7301525371923464192 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/1180007578420117504 current state:
# 4
# BatchPredictionJob run completed. Resource name: projects/39028607318/locations/us-central1/batchPredictionJobs/1180007578420117504
# Batch job projects/39028607318/locations/us-central1/batchPredictionJobs/1180007578420117504 started. Waiting for completion...
# Downloading and parsing results for batch_4...
# gs://wikipage-extraction/batch_6/batch_6.jsonl
# Launching batch_6...
# Creating BatchPredictionJob
# BatchPredictionJob created. Resource name: projects/39028607318/locations/us-central1/batchPredictionJobs/8290065490131288064
# To use this BatchPredictionJob in another session:
# bpj = aiplatform.BatchPredictionJob('projects/39028607318/locations/us-central1/batchPredictionJobs/8290065490131288064')
# View Batch Prediction Job:
# https://console.cloud.google.com/ai/platform/locations/us-central1/batch-predictions/8290065490131288064?project=39028607318
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/8290065490131288064 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/8290065490131288064 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/8290065490131288064 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/8290065490131288064 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/8290065490131288064 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/7301525371923464192 current state:
# 3
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/7301525371923464192 current state:
# 4
# BatchPredictionJob run completed. Resource name: projects/39028607318/locations/us-central1/batchPredictionJobs/7301525371923464192
# Batch job projects/39028607318/locations/us-central1/batchPredictionJobs/7301525371923464192 started. Waiting for completion...
# Downloading and parsing results for batch_5...
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/8290065490131288064 current state:
# 3
# gs://wikipage-extraction/batch_7/batch_7.jsonl
# Launching batch_7...
# Creating BatchPredictionJob
# BatchPredictionJob created. Resource name: projects/39028607318/locations/us-central1/batchPredictionJobs/1851606872851742720
# To use this BatchPredictionJob in another session:
# bpj = aiplatform.BatchPredictionJob('projects/39028607318/locations/us-central1/batchPredictionJobs/1851606872851742720')
# View Batch Prediction Job:
# https://console.cloud.google.com/ai/platform/locations/us-central1/batch-predictions/1851606872851742720?project=39028607318
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/1851606872851742720 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/1851606872851742720 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/1851606872851742720 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/1851606872851742720 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/1851606872851742720 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/8290065490131288064 current state:
# 3
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/8290065490131288064 current state:
# 4
# BatchPredictionJob run completed. Resource name: projects/39028607318/locations/us-central1/batchPredictionJobs/8290065490131288064
# Batch job projects/39028607318/locations/us-central1/batchPredictionJobs/8290065490131288064 started. Waiting for completion...
# Downloading and parsing results for batch_6...
# gs://wikipage-extraction/batch_8/batch_8.jsonl
# Launching batch_8...
# Creating BatchPredictionJob
# BatchPredictionJob created. Resource name: projects/39028607318/locations/us-central1/batchPredictionJobs/6839343460164567040
# To use this BatchPredictionJob in another session:
# bpj = aiplatform.BatchPredictionJob('projects/39028607318/locations/us-central1/batchPredictionJobs/6839343460164567040')
# View Batch Prediction Job:
# https://console.cloud.google.com/ai/platform/locations/us-central1/batch-predictions/6839343460164567040?project=39028607318
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/1851606872851742720 current state:
# 3
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/6839343460164567040 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/6839343460164567040 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/6839343460164567040 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/6839343460164567040 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/6839343460164567040 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/1851606872851742720 current state:
# 3
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/1851606872851742720 current state:
# 4
# BatchPredictionJob run completed. Resource name: projects/39028607318/locations/us-central1/batchPredictionJobs/1851606872851742720
# Batch job projects/39028607318/locations/us-central1/batchPredictionJobs/1851606872851742720 started. Waiting for completion...
# Downloading and parsing results for batch_7...
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/6839343460164567040 current state:
# 3
# gs://wikipage-extraction/batch_9/batch_9.jsonl
# Launching batch_9...
# Creating BatchPredictionJob
# BatchPredictionJob created. Resource name: projects/39028607318/locations/us-central1/batchPredictionJobs/3754940665369198592
# To use this BatchPredictionJob in another session:
# bpj = aiplatform.BatchPredictionJob('projects/39028607318/locations/us-central1/batchPredictionJobs/3754940665369198592')
# View Batch Prediction Job:
# https://console.cloud.google.com/ai/platform/locations/us-central1/batch-predictions/3754940665369198592?project=39028607318
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/3754940665369198592 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/3754940665369198592 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/3754940665369198592 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/3754940665369198592 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/3754940665369198592 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/6839343460164567040 current state:
# 3
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/6839343460164567040 current state:
# 4
# BatchPredictionJob run completed. Resource name: projects/39028607318/locations/us-central1/batchPredictionJobs/6839343460164567040
# Batch job projects/39028607318/locations/us-central1/batchPredictionJobs/6839343460164567040 started. Waiting for completion...
# Downloading and parsing results for batch_8...
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/3754940665369198592 current state:
# 3
# gs://wikipage-extraction/batch_10/batch_10.jsonl
# Launching batch_10...
# Creating BatchPredictionJob
# BatchPredictionJob created. Resource name: projects/39028607318/locations/us-central1/batchPredictionJobs/6264008607767986176
# To use this BatchPredictionJob in another session:
# bpj = aiplatform.BatchPredictionJob('projects/39028607318/locations/us-central1/batchPredictionJobs/6264008607767986176')
# View Batch Prediction Job:
# https://console.cloud.google.com/ai/platform/locations/us-central1/batch-predictions/6264008607767986176?project=39028607318
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/6264008607767986176 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/6264008607767986176 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/6264008607767986176 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/6264008607767986176 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/6264008607767986176 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/3754940665369198592 current state:
# 4
# BatchPredictionJob run completed. Resource name: projects/39028607318/locations/us-central1/batchPredictionJobs/3754940665369198592
# Batch job projects/39028607318/locations/us-central1/batchPredictionJobs/3754940665369198592 started. Waiting for completion...
# Downloading and parsing results for batch_9...
# gs://wikipage-extraction/batch_11/batch_11.jsonl
# Launching batch_11...
# Creating BatchPredictionJob
# BatchPredictionJob created. Resource name: projects/39028607318/locations/us-central1/batchPredictionJobs/1261353846689497088
# To use this BatchPredictionJob in another session:
# bpj = aiplatform.BatchPredictionJob('projects/39028607318/locations/us-central1/batchPredictionJobs/1261353846689497088')
# View Batch Prediction Job:
# https://console.cloud.google.com/ai/platform/locations/us-central1/batch-predictions/1261353846689497088?project=39028607318
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/1261353846689497088 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/6264008607767986176 current state:
# 3
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/1261353846689497088 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/1261353846689497088 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/1261353846689497088 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/1261353846689497088 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/6264008607767986176 current state:
# 4
# BatchPredictionJob run completed. Resource name: projects/39028607318/locations/us-central1/batchPredictionJobs/6264008607767986176
# Batch job projects/39028607318/locations/us-central1/batchPredictionJobs/6264008607767986176 started. Waiting for completion...
# Downloading and parsing results for batch_10...
# gs://wikipage-extraction/batch_12/batch_12.jsonl
# Launching batch_12...
# Creating BatchPredictionJob
# BatchPredictionJob created. Resource name: projects/39028607318/locations/us-central1/batchPredictionJobs/8300480064269582336
# To use this BatchPredictionJob in another session:
# bpj = aiplatform.BatchPredictionJob('projects/39028607318/locations/us-central1/batchPredictionJobs/8300480064269582336')
# View Batch Prediction Job:
# https://console.cloud.google.com/ai/platform/locations/us-central1/batch-predictions/8300480064269582336?project=39028607318
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/8300480064269582336 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/1261353846689497088 current state:
# 3
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/8300480064269582336 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/8300480064269582336 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/8300480064269582336 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/8300480064269582336 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/1261353846689497088 current state:
# 4
# BatchPredictionJob run completed. Resource name: projects/39028607318/locations/us-central1/batchPredictionJobs/1261353846689497088
# Batch job projects/39028607318/locations/us-central1/batchPredictionJobs/1261353846689497088 started. Waiting for completion...
# Downloading and parsing results for batch_11...
# gs://wikipage-extraction/batch_13/batch_13.jsonl
# Launching batch_13...
# Creating BatchPredictionJob
# BatchPredictionJob created. Resource name: projects/39028607318/locations/us-central1/batchPredictionJobs/5814493069961068544
# To use this BatchPredictionJob in another session:
# bpj = aiplatform.BatchPredictionJob('projects/39028607318/locations/us-central1/batchPredictionJobs/5814493069961068544')
# View Batch Prediction Job:
# https://console.cloud.google.com/ai/platform/locations/us-central1/batch-predictions/5814493069961068544?project=39028607318
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/8300480064269582336 current state:
# 3
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/5814493069961068544 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/5814493069961068544 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/5814493069961068544 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/5814493069961068544 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/5814493069961068544 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/8300480064269582336 current state:
# 4
# BatchPredictionJob run completed. Resource name: projects/39028607318/locations/us-central1/batchPredictionJobs/8300480064269582336
# Batch job projects/39028607318/locations/us-central1/batchPredictionJobs/8300480064269582336 started. Waiting for completion...
# Downloading and parsing results for batch_12...
# gs://wikipage-extraction/batch_14/batch_14.jsonl
# Launching batch_14...
# Creating BatchPredictionJob
# BatchPredictionJob created. Resource name: projects/39028607318/locations/us-central1/batchPredictionJobs/2506599143657439232
# To use this BatchPredictionJob in another session:
# bpj = aiplatform.BatchPredictionJob('projects/39028607318/locations/us-central1/batchPredictionJobs/2506599143657439232')
# View Batch Prediction Job:
# https://console.cloud.google.com/ai/platform/locations/us-central1/batch-predictions/2506599143657439232?project=39028607318
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/2506599143657439232 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/5814493069961068544 current state:
# 3
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/2506599143657439232 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/2506599143657439232 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/2506599143657439232 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/2506599143657439232 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/5814493069961068544 current state:
# 3
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/5814493069961068544 current state:
# 4
# BatchPredictionJob run completed. Resource name: projects/39028607318/locations/us-central1/batchPredictionJobs/5814493069961068544
# Batch job projects/39028607318/locations/us-central1/batchPredictionJobs/5814493069961068544 started. Waiting for completion...
# Downloading and parsing results for batch_13...
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/2506599143657439232 current state:
# 3
# gs://wikipage-extraction/batch_15/batch_15.jsonl
# Launching batch_15...
# Creating BatchPredictionJob
# BatchPredictionJob created. Resource name: projects/39028607318/locations/us-central1/batchPredictionJobs/7981850390633119744
# To use this BatchPredictionJob in another session:
# bpj = aiplatform.BatchPredictionJob('projects/39028607318/locations/us-central1/batchPredictionJobs/7981850390633119744')
# View Batch Prediction Job:
# https://console.cloud.google.com/ai/platform/locations/us-central1/batch-predictions/7981850390633119744?project=39028607318
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/7981850390633119744 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/7981850390633119744 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/7981850390633119744 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/7981850390633119744 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/7981850390633119744 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/2506599143657439232 current state:
# 3
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/2506599143657439232 current state:
# 4
# BatchPredictionJob run completed. Resource name: projects/39028607318/locations/us-central1/batchPredictionJobs/2506599143657439232
# Batch job projects/39028607318/locations/us-central1/batchPredictionJobs/2506599143657439232 started. Waiting for completion...
# Downloading and parsing results for batch_14...
# gs://wikipage-extraction/batch_16/batch_16.jsonl
# Launching batch_16...
# Creating BatchPredictionJob
# BatchPredictionJob created. Resource name: projects/39028607318/locations/us-central1/batchPredictionJobs/703470442848976896
# To use this BatchPredictionJob in another session:
# bpj = aiplatform.BatchPredictionJob('projects/39028607318/locations/us-central1/batchPredictionJobs/703470442848976896')
# View Batch Prediction Job:
# https://console.cloud.google.com/ai/platform/locations/us-central1/batch-predictions/703470442848976896?project=39028607318
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/703470442848976896 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/7981850390633119744 current state:
# 3
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/703470442848976896 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/703470442848976896 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/703470442848976896 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/703470442848976896 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/7981850390633119744 current state:
# 3
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/7981850390633119744 current state:
# 4
# BatchPredictionJob run completed. Resource name: projects/39028607318/locations/us-central1/batchPredictionJobs/7981850390633119744
# Batch job projects/39028607318/locations/us-central1/batchPredictionJobs/7981850390633119744 started. Waiting for completion...
# Downloading and parsing results for batch_15...
# gs://wikipage-extraction/batch_17/batch_17.jsonl
# Launching batch_17...
# Creating BatchPredictionJob
# BatchPredictionJob created. Resource name: projects/39028607318/locations/us-central1/batchPredictionJobs/4882810897048797184
# To use this BatchPredictionJob in another session:
# bpj = aiplatform.BatchPredictionJob('projects/39028607318/locations/us-central1/batchPredictionJobs/4882810897048797184')
# View Batch Prediction Job:
# https://console.cloud.google.com/ai/platform/locations/us-central1/batch-predictions/4882810897048797184?project=39028607318
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/703470442848976896 current state:
# 3
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/4882810897048797184 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/4882810897048797184 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/4882810897048797184 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/4882810897048797184 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/4882810897048797184 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/703470442848976896 current state:
# 4
# BatchPredictionJob run completed. Resource name: projects/39028607318/locations/us-central1/batchPredictionJobs/703470442848976896
# Batch job projects/39028607318/locations/us-central1/batchPredictionJobs/703470442848976896 started. Waiting for completion...
# Downloading and parsing results for batch_16...
# gs://wikipage-extraction/batch_18/batch_18.jsonl
# Launching batch_18...
# Creating BatchPredictionJob
# BatchPredictionJob created. Resource name: projects/39028607318/locations/us-central1/batchPredictionJobs/8860052317970366464
# To use this BatchPredictionJob in another session:
# bpj = aiplatform.BatchPredictionJob('projects/39028607318/locations/us-central1/batchPredictionJobs/8860052317970366464')
# View Batch Prediction Job:
# https://console.cloud.google.com/ai/platform/locations/us-central1/batch-predictions/8860052317970366464?project=39028607318
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/8860052317970366464 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/4882810897048797184 current state:
# 3
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/8860052317970366464 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/8860052317970366464 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/8860052317970366464 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/8860052317970366464 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/4882810897048797184 current state:
# 4
# BatchPredictionJob run completed. Resource name: projects/39028607318/locations/us-central1/batchPredictionJobs/4882810897048797184
# Batch job projects/39028607318/locations/us-central1/batchPredictionJobs/4882810897048797184 started. Waiting for completion...
# Downloading and parsing results for batch_17...
# gs://wikipage-extraction/batch_19/batch_19.jsonl
# Launching batch_19...
# Creating BatchPredictionJob
# BatchPredictionJob created. Resource name: projects/39028607318/locations/us-central1/batchPredictionJobs/782283436327960576
# To use this BatchPredictionJob in another session:
# bpj = aiplatform.BatchPredictionJob('projects/39028607318/locations/us-central1/batchPredictionJobs/782283436327960576')
# View Batch Prediction Job:
# https://console.cloud.google.com/ai/platform/locations/us-central1/batch-predictions/782283436327960576?project=39028607318
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/8860052317970366464 current state:
# 3
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/782283436327960576 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/782283436327960576 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/782283436327960576 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/782283436327960576 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/782283436327960576 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/8860052317970366464 current state:
# 4
# BatchPredictionJob run completed. Resource name: projects/39028607318/locations/us-central1/batchPredictionJobs/8860052317970366464
# Batch job projects/39028607318/locations/us-central1/batchPredictionJobs/8860052317970366464 started. Waiting for completion...
# Downloading and parsing results for batch_18...
# gs://wikipage-extraction/batch_20/batch_20.jsonl
# Launching batch_20...
# Creating BatchPredictionJob
# BatchPredictionJob created. Resource name: projects/39028607318/locations/us-central1/batchPredictionJobs/4433576834218590208
# To use this BatchPredictionJob in another session:
# bpj = aiplatform.BatchPredictionJob('projects/39028607318/locations/us-central1/batchPredictionJobs/4433576834218590208')
# View Batch Prediction Job:
# https://console.cloud.google.com/ai/platform/locations/us-central1/batch-predictions/4433576834218590208?project=39028607318
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/4433576834218590208 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/782283436327960576 current state:
# 3
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/4433576834218590208 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/4433576834218590208 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/4433576834218590208 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/4433576834218590208 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/782283436327960576 current state:
# 4
# BatchPredictionJob run completed. Resource name: projects/39028607318/locations/us-central1/batchPredictionJobs/782283436327960576
# Batch job projects/39028607318/locations/us-central1/batchPredictionJobs/782283436327960576 started. Waiting for completion...
# Downloading and parsing results for batch_19...
# gs://wikipage-extraction/batch_21/batch_21.jsonl
# Launching batch_21...
# Creating BatchPredictionJob
# BatchPredictionJob created. Resource name: projects/39028607318/locations/us-central1/batchPredictionJobs/2814532768178896896
# To use this BatchPredictionJob in another session:
# bpj = aiplatform.BatchPredictionJob('projects/39028607318/locations/us-central1/batchPredictionJobs/2814532768178896896')
# View Batch Prediction Job:
# https://console.cloud.google.com/ai/platform/locations/us-central1/batch-predictions/2814532768178896896?project=39028607318
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/2814532768178896896 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/2814532768178896896 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/2814532768178896896 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/4433576834218590208 current state:
# 3
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/2814532768178896896 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/2814532768178896896 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/4433576834218590208 current state:
# 4
# BatchPredictionJob run completed. Resource name: projects/39028607318/locations/us-central1/batchPredictionJobs/4433576834218590208
# Batch job projects/39028607318/locations/us-central1/batchPredictionJobs/4433576834218590208 started. Waiting for completion...
# Downloading and parsing results for batch_20...
# gs://wikipage-extraction/batch_22/batch_22.jsonl
# Launching batch_22...
# Creating BatchPredictionJob
# BatchPredictionJob created. Resource name: projects/39028607318/locations/us-central1/batchPredictionJobs/4539833637926862848
# To use this BatchPredictionJob in another session:
# bpj = aiplatform.BatchPredictionJob('projects/39028607318/locations/us-central1/batchPredictionJobs/4539833637926862848')
# View Batch Prediction Job:
# https://console.cloud.google.com/ai/platform/locations/us-central1/batch-predictions/4539833637926862848?project=39028607318
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/4539833637926862848 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/2814532768178896896 current state:
# 3
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/4539833637926862848 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/4539833637926862848 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/4539833637926862848 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/4539833637926862848 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/2814532768178896896 current state:
# 3
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/2814532768178896896 current state:
# 4
# BatchPredictionJob run completed. Resource name: projects/39028607318/locations/us-central1/batchPredictionJobs/2814532768178896896
# Batch job projects/39028607318/locations/us-central1/batchPredictionJobs/2814532768178896896 started. Waiting for completion...
# Downloading and parsing results for batch_21...
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/4539833637926862848 current state:
# 3
# gs://wikipage-extraction/batch_23/batch_23.jsonl
# Launching batch_23...
# Creating BatchPredictionJob
# BatchPredictionJob created. Resource name: projects/39028607318/locations/us-central1/batchPredictionJobs/2337151207677624320
# To use this BatchPredictionJob in another session:
# bpj = aiplatform.BatchPredictionJob('projects/39028607318/locations/us-central1/batchPredictionJobs/2337151207677624320')
# View Batch Prediction Job:
# https://console.cloud.google.com/ai/platform/locations/us-central1/batch-predictions/2337151207677624320?project=39028607318
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/2337151207677624320 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/2337151207677624320 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/2337151207677624320 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/2337151207677624320 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/2337151207677624320 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/4539833637926862848 current state:
# 3
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/4539833637926862848 current state:
# 4
# BatchPredictionJob run completed. Resource name: projects/39028607318/locations/us-central1/batchPredictionJobs/4539833637926862848
# Batch job projects/39028607318/locations/us-central1/batchPredictionJobs/4539833637926862848 started. Waiting for completion...
# Downloading and parsing results for batch_22...
# gs://wikipage-extraction/batch_24/batch_24.jsonl
# Launching batch_24...
# Creating BatchPredictionJob
# BatchPredictionJob created. Resource name: projects/39028607318/locations/us-central1/batchPredictionJobs/3850360682474110976
# To use this BatchPredictionJob in another session:
# bpj = aiplatform.BatchPredictionJob('projects/39028607318/locations/us-central1/batchPredictionJobs/3850360682474110976')
# View Batch Prediction Job:
# https://console.cloud.google.com/ai/platform/locations/us-central1/batch-predictions/3850360682474110976?project=39028607318
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/3850360682474110976 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/2337151207677624320 current state:
# 3
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/3850360682474110976 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/3850360682474110976 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/3850360682474110976 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/3850360682474110976 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/2337151207677624320 current state:
# 4
# BatchPredictionJob run completed. Resource name: projects/39028607318/locations/us-central1/batchPredictionJobs/2337151207677624320
# Batch job projects/39028607318/locations/us-central1/batchPredictionJobs/2337151207677624320 started. Waiting for completion...
# Downloading and parsing results for batch_23...
# gs://wikipage-extraction/batch_25/batch_25.jsonl
# Launching batch_25...
# Creating BatchPredictionJob
# BatchPredictionJob created. Resource name: projects/39028607318/locations/us-central1/batchPredictionJobs/4213322664942501888
# To use this BatchPredictionJob in another session:
# bpj = aiplatform.BatchPredictionJob('projects/39028607318/locations/us-central1/batchPredictionJobs/4213322664942501888')
# View Batch Prediction Job:
# https://console.cloud.google.com/ai/platform/locations/us-central1/batch-predictions/4213322664942501888?project=39028607318
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/4213322664942501888 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/3850360682474110976 current state:
# 3
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/4213322664942501888 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/4213322664942501888 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/4213322664942501888 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/4213322664942501888 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/3850360682474110976 current state:
# 3
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/4213322664942501888 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/3850360682474110976 current state:
# 4
# BatchPredictionJob run completed. Resource name: projects/39028607318/locations/us-central1/batchPredictionJobs/3850360682474110976
# Batch job projects/39028607318/locations/us-central1/batchPredictionJobs/3850360682474110976 started. Waiting for completion...
# Downloading and parsing results for batch_24...
# gs://wikipage-extraction/batch_26/batch_26.jsonl
# Launching batch_26...
# Creating BatchPredictionJob
# BatchPredictionJob created. Resource name: projects/39028607318/locations/us-central1/batchPredictionJobs/3257433644033114112
# To use this BatchPredictionJob in another session:
# bpj = aiplatform.BatchPredictionJob('projects/39028607318/locations/us-central1/batchPredictionJobs/3257433644033114112')
# View Batch Prediction Job:
# https://console.cloud.google.com/ai/platform/locations/us-central1/batch-predictions/3257433644033114112?project=39028607318
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/3257433644033114112 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/3257433644033114112 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/3257433644033114112 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/3257433644033114112 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/3257433644033114112 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/4213322664942501888 current state:
# 3
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/4213322664942501888 current state:
# 4
# BatchPredictionJob run completed. Resource name: projects/39028607318/locations/us-central1/batchPredictionJobs/4213322664942501888
# Batch job projects/39028607318/locations/us-central1/batchPredictionJobs/4213322664942501888 started. Waiting for completion...
# Downloading and parsing results for batch_25...
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/3257433644033114112 current state:
# 3
# gs://wikipage-extraction/batch_27/batch_27.jsonl
# Launching batch_27...
# Creating BatchPredictionJob
# BatchPredictionJob created. Resource name: projects/39028607318/locations/us-central1/batchPredictionJobs/8977005170793644032
# To use this BatchPredictionJob in another session:
# bpj = aiplatform.BatchPredictionJob('projects/39028607318/locations/us-central1/batchPredictionJobs/8977005170793644032')
# View Batch Prediction Job:
# https://console.cloud.google.com/ai/platform/locations/us-central1/batch-predictions/8977005170793644032?project=39028607318
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/8977005170793644032 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/8977005170793644032 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/8977005170793644032 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/8977005170793644032 current state:
# 2
# ...
# BatchPredictionJob created. Resource name: projects/39028607318/locations/us-central1/batchPredictionJobs/1139404813029605376
# To use this BatchPredictionJob in another session:
# bpj = aiplatform.BatchPredictionJob('projects/39028607318/locations/us-central1/batchPredictionJobs/1139404813029605376')
# View Batch Prediction Job:
# https://console.cloud.google.com/ai/platform/locations/us-central1/batch-predictions/1139404813029605376?project=39028607318
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/1139404813029605376 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/1139404813029605376 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/1139404813029605376 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/1139404813029605376 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/1139404813029605376 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/5457230955771068416 current state:
# 4
# BatchPredictionJob run completed. Resource name: projects/39028607318/locations/us-central1/batchPredictionJobs/5457230955771068416
# Batch job projects/39028607318/locations/us-central1/batchPredictionJobs/5457230955771068416 started. Waiting for completion...
# Downloading and parsing results for batch_78...
# gs://wikipage-extraction/batch_80/batch_80.jsonl
# Launching batch_80...
# Creating BatchPredictionJob
# BatchPredictionJob created. Resource name: projects/39028607318/locations/us-central1/batchPredictionJobs/4206356159268913152
# To use this BatchPredictionJob in another session:
# bpj = aiplatform.BatchPredictionJob('projects/39028607318/locations/us-central1/batchPredictionJobs/4206356159268913152')
# View Batch Prediction Job:
# https://console.cloud.google.com/ai/platform/locations/us-central1/batch-predictions/4206356159268913152?project=39028607318
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/4206356159268913152 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/4206356159268913152 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/4206356159268913152 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/1139404813029605376 current state:
# 3
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/4206356159268913152 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/4206356159268913152 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/1139404813029605376 current state:
# 4
# BatchPredictionJob run completed. Resource name: projects/39028607318/locations/us-central1/batchPredictionJobs/1139404813029605376
# Batch job projects/39028607318/locations/us-central1/batchPredictionJobs/1139404813029605376 started. Waiting for completion...
# Downloading and parsing results for batch_79...
# gs://wikipage-extraction/batch_81/batch_81.jsonl
# Launching batch_81...
# Creating BatchPredictionJob
# BatchPredictionJob created. Resource name: projects/39028607318/locations/us-central1/batchPredictionJobs/5219679269566808064
# To use this BatchPredictionJob in another session:
# bpj = aiplatform.BatchPredictionJob('projects/39028607318/locations/us-central1/batchPredictionJobs/5219679269566808064')
# View Batch Prediction Job:
# https://console.cloud.google.com/ai/platform/locations/us-central1/batch-predictions/5219679269566808064?project=39028607318
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/5219679269566808064 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/4206356159268913152 current state:
# 3
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/5219679269566808064 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/5219679269566808064 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/5219679269566808064 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/5219679269566808064 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/4206356159268913152 current state:
# 4
# BatchPredictionJob run completed. Resource name: projects/39028607318/locations/us-central1/batchPredictionJobs/4206356159268913152
# Batch job projects/39028607318/locations/us-central1/batchPredictionJobs/4206356159268913152 started. Waiting for completion...
# Downloading and parsing results for batch_80...
# gs://wikipage-extraction/batch_82/batch_82.jsonl
# Launching batch_82...
# Creating BatchPredictionJob
# BatchPredictionJob created. Resource name: projects/39028607318/locations/us-central1/batchPredictionJobs/1472671185455022080
# To use this BatchPredictionJob in another session:
# bpj = aiplatform.BatchPredictionJob('projects/39028607318/locations/us-central1/batchPredictionJobs/1472671185455022080')
# View Batch Prediction Job:
# https://console.cloud.google.com/ai/platform/locations/us-central1/batch-predictions/1472671185455022080?project=39028607318
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/1472671185455022080 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/5219679269566808064 current state:
# 3
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/1472671185455022080 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/1472671185455022080 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/1472671185455022080 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/1472671185455022080 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/5219679269566808064 current state:
# 4
# BatchPredictionJob run completed. Resource name: projects/39028607318/locations/us-central1/batchPredictionJobs/5219679269566808064
# Batch job projects/39028607318/locations/us-central1/batchPredictionJobs/5219679269566808064 started. Waiting for completion...
# Downloading and parsing results for batch_81...
# gs://wikipage-extraction/batch_83/batch_83.jsonl
# Launching batch_83...
# Creating BatchPredictionJob
# BatchPredictionJob created. Resource name: projects/39028607318/locations/us-central1/batchPredictionJobs/7125827811851370496
# To use this BatchPredictionJob in another session:
# bpj = aiplatform.BatchPredictionJob('projects/39028607318/locations/us-central1/batchPredictionJobs/7125827811851370496')
# View Batch Prediction Job:
# https://console.cloud.google.com/ai/platform/locations/us-central1/batch-predictions/7125827811851370496?project=39028607318
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/7125827811851370496 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/7125827811851370496 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/1472671185455022080 current state:
# 3
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/7125827811851370496 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/7125827811851370496 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/7125827811851370496 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/1472671185455022080 current state:
# 4
# BatchPredictionJob run completed. Resource name: projects/39028607318/locations/us-central1/batchPredictionJobs/1472671185455022080
# Batch job projects/39028607318/locations/us-central1/batchPredictionJobs/1472671185455022080 started. Waiting for completion...
# Downloading and parsing results for batch_82...
# gs://wikipage-extraction/batch_84/batch_84.jsonl
# Launching batch_84...
# Creating BatchPredictionJob
# BatchPredictionJob created. Resource name: projects/39028607318/locations/us-central1/batchPredictionJobs/4299819045676384256
# To use this BatchPredictionJob in another session:
# bpj = aiplatform.BatchPredictionJob('projects/39028607318/locations/us-central1/batchPredictionJobs/4299819045676384256')
# View Batch Prediction Job:
# https://console.cloud.google.com/ai/platform/locations/us-central1/batch-predictions/4299819045676384256?project=39028607318
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/4299819045676384256 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/7125827811851370496 current state:
# 3
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/4299819045676384256 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/4299819045676384256 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/4299819045676384256 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/4299819045676384256 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/7125827811851370496 current state:
# 4
# BatchPredictionJob run completed. Resource name: projects/39028607318/locations/us-central1/batchPredictionJobs/7125827811851370496
# Batch job projects/39028607318/locations/us-central1/batchPredictionJobs/7125827811851370496 started. Waiting for completion...
# Downloading and parsing results for batch_83...
# gs://wikipage-extraction/batch_85/batch_85.jsonl
# Launching batch_85...
# Creating BatchPredictionJob
# BatchPredictionJob created. Resource name: projects/39028607318/locations/us-central1/batchPredictionJobs/9025783904648298496
# To use this BatchPredictionJob in another session:
# bpj = aiplatform.BatchPredictionJob('projects/39028607318/locations/us-central1/batchPredictionJobs/9025783904648298496')
# View Batch Prediction Job:
# https://console.cloud.google.com/ai/platform/locations/us-central1/batch-predictions/9025783904648298496?project=39028607318
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/4299819045676384256 current state:
# 3
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/9025783904648298496 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/9025783904648298496 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/9025783904648298496 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/9025783904648298496 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/9025783904648298496 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/4299819045676384256 current state:
# 3
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/4299819045676384256 current state:
# 4
# BatchPredictionJob run completed. Resource name: projects/39028607318/locations/us-central1/batchPredictionJobs/4299819045676384256
# Batch job projects/39028607318/locations/us-central1/batchPredictionJobs/4299819045676384256 started. Waiting for completion...
# Downloading and parsing results for batch_84...
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/9025783904648298496 current state:
# 3
# gs://wikipage-extraction/batch_86/batch_86.jsonl
# Launching batch_86...
# Creating BatchPredictionJob
# BatchPredictionJob created. Resource name: projects/39028607318/locations/us-central1/batchPredictionJobs/966592371468795904
# To use this BatchPredictionJob in another session:
# bpj = aiplatform.BatchPredictionJob('projects/39028607318/locations/us-central1/batchPredictionJobs/966592371468795904')
# View Batch Prediction Job:
# https://console.cloud.google.com/ai/platform/locations/us-central1/batch-predictions/966592371468795904?project=39028607318
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/966592371468795904 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/966592371468795904 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/966592371468795904 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/966592371468795904 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/966592371468795904 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/9025783904648298496 current state:
# 3
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/9025783904648298496 current state:
# 4
# BatchPredictionJob run completed. Resource name: projects/39028607318/locations/us-central1/batchPredictionJobs/9025783904648298496
# Batch job projects/39028607318/locations/us-central1/batchPredictionJobs/9025783904648298496 started. Waiting for completion...
# Downloading and parsing results for batch_85...
# gs://wikipage-extraction/batch_87/batch_87.jsonl
# Launching batch_87...
# Creating BatchPredictionJob
# BatchPredictionJob created. Resource name: projects/39028607318/locations/us-central1/batchPredictionJobs/223498432952664064
# To use this BatchPredictionJob in another session:
# bpj = aiplatform.BatchPredictionJob('projects/39028607318/locations/us-central1/batchPredictionJobs/223498432952664064')
# View Batch Prediction Job:
# https://console.cloud.google.com/ai/platform/locations/us-central1/batch-predictions/223498432952664064?project=39028607318
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/223498432952664064 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/966592371468795904 current state:
# 3
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/223498432952664064 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/223498432952664064 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/223498432952664064 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/223498432952664064 current state:
# 2
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/966592371468795904 current state:
# 4
# BatchPredictionJob run completed. Resource name: projects/39028607318/locations/us-central1/batchPredictionJobs/966592371468795904
# Batch job projects/39028607318/locations/us-central1/batchPredictionJobs/966592371468795904 started. Waiting for completion...
# Downloading and parsing results for batch_86...
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/223498432952664064 current state:
# 3
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/223498432952664064 current state:
# 3
# BatchPredictionJob projects/39028607318/locations/us-central1/batchPredictionJobs/223498432952664064 current state:
# 4
# BatchPredictionJob run completed. Resource name: projects/39028607318/locations/us-central1/batchPredictionJobs/223498432952664064
# Batch job projects/39028607318/locations/us-central1/batchPredictionJobs/223498432952664064 started. Waiting for completion...
# Downloading and parsing results for batch_87...
# Failed 1788
# Errored 1793
# Events 1990721
# Usage {'promptTokenCount': 309176126, 'candidatesTokenCount': 131500777}

# %%
counter = 0
with db_utils.open_plyvel_db(
    "events_extracted_by_page_gemini-2.0-flash_db", replace=False
) as db:
    for page_title, data in db.iterator():
        counter += 1
counter
# Out:
# 372188

# %%
150k pages / 100$
# Out:
# 1.488

# %%
67c per 1000 pages
